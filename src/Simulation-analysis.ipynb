# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
def burn_in(data, nb_burn):
    """ data : a list of lists """
    return tuple([sub_data[nb_burn:] for sub_data in data])

def plot_posteriors(simulation_dict) :
    """"""
    pass

def to_ratio(data):
    return([np.exp(data[i]) for i in range(len(data))])

# %%
log_dir = "/home/mehdi/PycharmProjects/JeffreyPriorMM/src/logs/"
filename = "Sat Jan 27 19:14:39 2018-simulation-data.json"
# Read the json file
simulation_data = json.load(open(log_dir + filename))

# %%
print(simulation_data.keys())
# Out:
# dict_keys(['diffs_1', 'acc', 'sigma', 'diffs_2', 'mu', 'w'])

# %%
simulation_data["sigma"]
# Out:
# [[2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
#  [2.797110467411077, 2.6175691857877963],
# ...

# %%
to_ratio(simulation_data["diffs_1"])
# Out:
# /home/mehdi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:10: RuntimeWarning: overflow encountered in exp
# [inf,
#  2.2858516476667102e-77,
#  3.6586633956923527e-69,
#  4.672359391452213e-79,
#  5.31174995204101e-73,
#  4.733200452885491e-80,
#  4.9976563286982964e-76,
#  4.0606369744947655e-78,
#  5.798112486548891e-74,
#  4.232491446075748e-74,
#  4.508106442589531e-77,
#  2.8860414269674654e-87,
#  3.808629531611294e-79,
#  2.605384416378232e-75,
#  5.52196613405494e-71,
#  1.5120836426172176e-88,
#  9.215269583071388e-65,
#  1.7768189022267965e-87,
#  1.380025552042271e-61,
#  4.521131853559914e-80,
#  4.531891084109441e-80,
#  1.157391857498313e-75,
#  1.3060723329286996e-78,
#  3.995108608731253e-76,
#  2.079150612240615e-72,
#  1.3314840661453476e-81,
#  2.961147846423996e-78,
#  3.985458989508124e-77,
#  2.8830219087356957e-80,
#  2.9743663776144676e-84,
#  1.2481829373225789e-80,
#  3.452093796616219e-80,
#  5.727566940801905e-76,
# ...

# %%
sns.distplot(x)
